# %%
# %matplotlib inline
import matplotlib as lib
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Top Grossing Movies:
# 1. Get the data
# 2. Clean and data
# 3. Transform to Pandas framework
# 4. Do calculation if neccessary
# 5. Explore!

# %%
#Get the data and clean the data
t=requests.get("http://www.the-numbers.com/movie/records/All-Time-Domestic-Box-Office")
soup=BeautifulSoup(t.text)
soup.prettify()
tgm=soup.find_all("tr")
topGrossingMovies={'Movie Name':[],"Year":[],"Domestic Box Office":[], "International Box Office":[],"Worldwide Box Office": []}
for i in range(1, len(tgm)):
    x= tgm[i].find_all("td")
    topGrossingMovies['Year'].append(int(x[1].get_text().strip()))
    topGrossingMovies['Movie Name'].append(x[2].get_text().strip())    
    topGrossingMovies['Domestic Box Office'].append(int(x[3].get_text().replace('$','').replace(',','').strip()))
    topGrossingMovies['International Box Office'].append(int(x[4].get_text().replace('$','').replace(',','').strip()))
    topGrossingMovies['Worldwide Box Office'].append(int(x[5].get_text().replace('$','').replace(',','').strip()))
topGrossingMovies
# Out:
# /usr/local/lib/python3.5/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# {'Domestic Box Office': [936662225,
#   760507625,
#   658672302,
#   652198010,
#   623279547,
#   533345358,
#   483572795,
#   474544677,
#   460998007,
#   459005868,
#   448139099,
#   441226247,
#   435110554,
#   424668047,
#   423315812,
#   422780140,
#   415004880,
#   408992272,
#   408061789,
#   408010692,
#   403706375,
#   402111870,
#   400738009,
#   395708305,
#   381011219,
#   380529370,
#   380270577,
#   377845905,
#   373524485,
#   370782930,
# ...

# %%
# Put the data into framework
bdf=pd.DataFrame(topGrossingMovies)
bdf=bdf[['Movie Name','Year','Domestic Box Office','International Box Office','Worldwide Box Office']]
bdf.index=bdf.index +1
bdf
# Out:
#                                             Movie Name  Year  \
# 1                 Star Wars Ep. VII: The Force Awakens  2015
# 2                                               Avatar  2009
# 3                                              Titanic  1997
# 4                                       Jurassic World  2015
# 5                                         The Avengers  2012
# 6                                      The Dark Knight  2008
# 7                                         Finding Dory  2016
# 8                  Star Wars Ep. I: The Phantom Menace  1999
# 9                         Star Wars Ep. IV: A New Hope  1977
# 10                             Avengers: Age of Ultron  2015
# 11                               The Dark Knight Rises  2012
# 12                                             Shrek 2  2004
# 13                           ET: The Extra-Terrestrial  1982
# 14                     The Hunger Games: Catching Fire  2013
# ...

# %%
bdf.to_csv("TopGrossingMovies.csv")

# %%
#get CPI data
cpidata = pd.read_excel("cpi_data.xlsx", skiprows=range(9), header=1)
cols=list(cpidata)
cols.remove('Year')
cols.remove('HALF1')
cols.remove('HALF2')
cpidata["Average"]=cpidata[cols].mean(axis=1)
cpia=cpidata[['Year','Average']]
# cpia=cpia.set_index(keys="Year")
cpia.tail()
# Out:
#     Year     Average
# 48  2012  229.593917
# 49  2013  232.957083
# 50  2014  236.736167
# 51  2015  237.017000
# 52  2016  238.782333
